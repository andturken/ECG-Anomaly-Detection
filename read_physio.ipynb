# %%
import numpy as np
import pandas as pd
import scipy.io.matlab as mat

phys_mat = mat.loadmat('s2s_mitbih_aami.mat')

# %%
#keys = phys_mat.keys()
keys
phys_mat['__header__']
phys_mat['__version__']
phys_mat['__globals__']
phys = phys_mat['s2s_mitbih']
type(phys)
phys[0]

# %%
# sjs_phys = []
# for
p = phys[0]
type(p)
p[47]
;
# Out:
# ''

# %%
p[47]
type(p)
;
# Out:
# ''

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(p[47])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-a10faf3130be> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.plot(p[47])
#       4
#       5
#
# C:\software\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# C:\software\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# -> 1667             self.add_line(line)
#    1668         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1669         return lines
#
# C:\software\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1900             line.set_clip_path(self.patch)
#    1901
# -> 1902         self._update_line_limits(line)
#    1903         if not line.get_label():
#    1904             line.set_label('_line%d' % len(self.lines))
#
# C:\software\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1922         Figures out the data limit of the given line, updating self.dataLim.
#    1923         """
# -> 1924         path = line.get_path()
#    1925         if path.vertices.size == 0:
#    1926             return
#
# C:\software\anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# C:\software\anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     673         if always or self._invalidy:
#     674             yconv = self.convert_yunits(self._yorig)
# --> 675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#     677             y = self._y
#
# C:\software\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1388         return np.ma.asarray(x, float).filled(np.nan)
#    1389     else:
# -> 1390         return np.asarray(x, float)
#    1391
#    1392
#
# C:\software\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# TypeError: Cannot cast array data from dtype([('seg_values', 'O'), ('seg_labels', 'O')]) to dtype('float64') according to the rule 'unsafe'

# %%
plt.plot(p[47][1])
plt.show()

# %%
p[30][1]
# Out:
# array(['...'],
#       dtype='<U3000')
